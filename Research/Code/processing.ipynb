# %%
import pandas as pd

data = pd.read_csv('sp500_transcripts_history.csv')
data.head()
# Out:
#                         company quarter  year  \
# 0             Apple Inc. (AAPL)      Q1  2025
# 1             Apple Inc. (AAPL)      Q3  2025
# 2  Microsoft Corporation (MSFT)      Q1  2025
# 3  Microsoft Corporation (MSFT)      Q2  2025
# 4  Microsoft Corporation (MSFT)      Q4  2025
#
#                                                title  \
# 0      Apple (AAPL) Q1 2025 Earnings Call Transcript
# 1      Apple (AAPL) Q3 2025 Earnings Call Transcript
# 2  Microsoft (MSFT) Q1 2025 Earnings Call Transcript
# 3  Microsoft (MSFT) Q2 2025 Earnings Call Transcript
# 4  Microsoft (MSFT) Q4 2025 Earnings Call Transcript
#
#                                                  url  \
# 0  https://www.fool.com/earnings/call-transcripts...
# 1  https://www.fool.com/earnings/call-transcripts...
# 2  https://www.fool.com/earnings/call-transcripts...
# 3  https://www.fool.com/earnings/call-transcripts...
# 4  https://www.fool.com/earnings/call-transcripts...
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   company  389 non-null    str
#  1   quarter  389 non-null    str
#  2   year     389 non-null    int64
#  3   title    389 non-null    str
#  4   url      389 non-null    str
#  5   content  389 non-null    str
# dtypes: int64(1), str(5)
# memory usage: 18.4 KB
